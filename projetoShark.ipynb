# %% [markdown]
# # Tipo de atividade x tipo ferimento

# %%
import pandas as pd
import numpy as np
import os

# %%
cd Ironhack/projeto
# Out:
# /home/felipe/Ironhack/projeto

# %%
df_fonte=pd.read_csv('/home/felipe/Ironhack/projeto/attacks.csv', encoding = 'latin-1')
df = df_fonte.copy()

# %%
def clean_colnames(df):
    '''Clean columns names when passing a pandas dataframe: params (df - dataframe)'''
    col_clean = []
    for col in df.columns:
        col = col.strip().lower()
        col = col.replace('.',' ')
        col_clean.append(col)
        
    df.columns = col_clean
    return df.columns

# %%
clean_colnames(df)
# Out:
# Index(['case number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal (y/n)', 'time',
#        'species', 'investigator or source', 'pdf', 'href formula', 'href',
#        'case number 1', 'case number 2', 'original order', 'unnamed: 22',
#        'unnamed: 23'],
#       dtype='object')

# %%
df.head(50)
# Out:
#      case number                  date    year          type        country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating            USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked            USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid            USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked         MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked            USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked            USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked            USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked      AUSTRALIA
# ...

# %%
df = df.drop(axis = 1, columns = ['unnamed: 22', 'year', 'date','location', 'unnamed: 23', 'href', 'href formula', 'pdf', 'original order',
                                  'investigator or source', 'fatal (y/n)', 'case number 1', 
                                  'case number 2', 'type', 'name', 'species', 'case number', 'case number','age','sex','time','area','country'])

# %%
df=df.dropna(subset=['activity','injury'])

# %%
df['activity_sint'] = df['activity']
acoes = ['surfing', 'swimming', 'fishing', 'spearfishing', 'bathing', 'wading', 'diving','standing', 'snorkeling', 'scuba diving' , 'body boarding', 'body surfing', 'kayaking', 'fell overboard', 'pearl diving', 'treading water', 'boogie boarding', 'paddling', 'walking', 'cleaning fish', 'playing', 'standing', 'kite boarding' , 'spearfishing', 'feeding shark', 'bathing', 'kite surfing', 'body surfing']         
for i, row in df.iterrows():
    for acao in acoes:
        if isinstance(df['activity'][i], str) and acao in df['activity'][i].lower():
            df['activity_sint'][i]  = acao
            break
        df['activity_sint'][i] = 'others'

# %%
df['injury_sint'] = df['injury']
gravidade = ['no injury', 'minor', 'injured', 'severe', 'serious', 'fatal', 'bite','bitten','puncture','laceration', 'wounds','abrasion', 'bruise']
for i, row in df.iterrows():
    for item in gravidade:
        if isinstance(df['injury'][i], str) and item in df['injury'][i].lower():
            df['injury_sint'][i] = item
            break
        df['injury_sint'][i] = 'others'

# %%
df['part_sint'] = df['injury']
parte = ['leg','foot','thigh','knee','ankle','calf','heel','arm','hand','finger','toes','forearm','abdomen','face','neck']
for i, row in df.iterrows():
    for item in parte:
        if isinstance(df['injury'][i], str) and item in df['injury'][i].lower():
            df['part_sint'][i] = item
            break
        df['part_sint'][i] = 'others'

# %%
df['activity_sint'].value_counts()
# Out:
# fishing            1160
# surfing            1121
# swimming           1108
# others              936
# diving              526
# bathing             189
# wading              164
# standing            131
# snorkeling           94
# body boarding        65
# fell overboard       56
# boogie boarding      46
# treading water       37
# kayaking             36
# playing              23
# walking              22
# paddling             17
# feeding shark         5
# kite boarding         4
# cleaning fish         2
# Name: activity_sint, dtype: int64

# %%
df['injury_sint'].value_counts()
# Out:
# fatal         1102
# bitten        1093
# others        1023
# no injury      758
# laceration     655
# severe         438
# minor          229
# puncture       199
# injured        132
# bite            43
# abrasion        31
# bruise          26
# wounds           7
# serious          6
# Name: injury_sint, dtype: int64

# %%
df['part_sint'].value_counts()
# Out:
# others     2492
# leg         931
# foot        688
# arm         449
# thigh       366
# hand        289
# calf        178
# ankle       116
# knee         74
# finger       57
# heel         35
# abdomen      24
# face         22
# toes         12
# neck          9
# Name: part_sint, dtype: int64

# %%
df.head(50)
# Out:
#                     activity  \
# 0                   Paddling
# 1                   Standing
# 2                    Surfing
# 3                    Surfing
# 4                Free diving
# 5               Kite surfing
# 6                   Swimming
# 7                    Fishing
# 8                    Walking
# 9                   Standing
# 10            Feeding sharks
# 11           Boogie boarding
# 12                  Swimming
# 13                   Fishing
# 14            Feeding sharks
# 15                   Surfing
# 16                   Surfing
# 17                  Swimming
# 18              Scuba diving
# 19                   Surfing
# 20                   Surfing
# 21                   Surfing
# 22                   Surfing
# 23                   Fishing
# 24             Paddle-skiing
# 25             Body boarding
# 26                  Swimming
# 27                  Swimming
# 28                   Surfing
# 29                   Surfing
# 30                   Surfing
# ...

# %%
df.groupby(['activity_sint','injury_sint']).count()
# Out:
#                            activity  injury  part_sint
# activity_sint injury_sint
# bathing       bitten             33      33         33
#               bruise              1       1          1
#               fatal              77      77         77
#               injured             4       4          4
#               laceration         18      18         18
# ...                             ...     ...        ...
# walking       laceration          3       3          3
#               minor               2       2          2
#               no injury           1       1          1
#               others              4       4          4
#               puncture            2       2          2
#
# [177 rows x 3 columns]

# %%
df.groupby(['activity_sint','part_sint']).count()
# Out:
#                          activity  injury  injury_sint
# activity_sint part_sint
# bathing       abdomen           1       1            1
#               ankle             2       2            2
#               arm              13      13           13
#               calf              4       4            4
#               finger            1       1            1
# ...                           ...     ...          ...
# walking       arm               2       2            2
#               foot              4       4            4
#               heel              1       1            1
#               leg              10      10           10
#               others            4       4            4
#
# [179 rows x 3 columns]

# %%
df['actXpart'] = df['activity_sint'] +' '+df['part_sint']

# %%
df['actXpart'].value_counts()
# Out:
# others others         591
# fishing others        559
# swimming others       456
# surfing others        314
# surfing foot          285
#                      ...
# wading abdomen          1
# body boarding heel      1
# others neck             1
# standing knee           1
# paddling ankle          1
# Name: actXpart, Length: 179, dtype: int64
